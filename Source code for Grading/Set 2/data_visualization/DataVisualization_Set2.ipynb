# %% [markdown]
# Author: Armin Irvije

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.figure_factory as ff
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from IPython.display import display
from sklearn.svm import OneClassSVM
from numpy import where

# %% [markdown]
# # Correlation Matrix

# %%
file =  pd.read_csv("../../data/cleaned_all_phones.csv")



# Calculate the correlation matrix for all numeric columns
correlation_matrix = file.corr(numeric_only=True)

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                 inches   battery   ram(GB)  weight(g)  storage(GB)  \
# inches        1.000000  0.673548  0.533778   0.779829     0.490416
# battery       0.673548  1.000000  0.360098   0.547308     0.257782
# ram(GB)       0.533778  0.360098  1.000000   0.377633     0.699045
# weight(g)     0.779829  0.547308  0.377633   1.000000     0.377427
# storage(GB)   0.490416  0.257782  0.699045   0.377427     1.000000
# video_720p    0.165955 -0.062071  0.460389   0.173867     0.423172
# video_1080p   0.174925  0.145556  0.105559   0.071146     0.081169
# video_4K      0.206591 -0.031378  0.487847   0.193385     0.444196
# video_8K      0.187832  0.102949  0.267722   0.228986     0.224257
# video_30fps  -0.133289 -0.060585 -0.195981  -0.123157    -0.204475
# video_60fps   0.194546 -0.007118  0.384060   0.231560     0.360365
# video_120fps  0.060650 -0.075968  0.260361   0.083563     0.214213
# video_240fps  0.064011 -0.109209  0.207934   0.134970     0.223122
# ...

# %%
#check data type of each column
data_type = file['ram(GB)'].dtype
print(f'Data type of column_name: {data_type}')
# Out:
# Data type of column_name: int64

# %% [markdown]
# # Box Plots

# %%
sns.boxplot(data=file[['inches']])
plt.show() 

sns.boxplot(data=file[['battery']])
plt.show()  

sns.boxplot(data = file[['price(USD)']])
plt.show()   

sns.boxplot(data = file[['weight(g)']])
plt.show()  

sns.boxplot(data = file[['ram(GB)']])
plt.show()  

sns.boxplot(data = file[['storage(GB)']])
plt.show()

# %% [markdown]
# # Pairplot

# %%
# I only want to pairplot numerical columns
selected_columns = ['inches', 'battery', 'ram(GB)', 'weight(g)', 'storage(GB)', 'price(USD)']
data = file[selected_columns]

pd.plotting.scatter_matrix(data,  figsize=(12, 12), alpha=1)
plt.show()

# %% [markdown]
#  # Analysis

# %% [markdown]
# After visualizing the dataset:
# Only 6 columns are integer/floats datatypes
# The correlation matrix shows that no attribute has strong corelation with price
