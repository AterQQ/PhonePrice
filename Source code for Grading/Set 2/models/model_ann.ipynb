# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import confusion_matrix, f1_score, classification_report
import numpy as np
import seaborn as sns
# Load the dataset
file_path = '../../data/cleaned_all_phones.csv'
phone_data = pd.read_csv(file_path)

# Define custom price categories
bins = [0, 250, 500, 1000, phone_data['price(USD)'].max()]
labels = ['0-250', '251-500', '501-1000', '1000+']
phone_data['price_category'] = pd.cut(phone_data['price(USD)'], bins=bins, labels=labels, right=False)

# Selecting features and target variable
features = ['storage(GB)', 'video_4K', 'video_720p', 'ram(GB)', 'video_60fps', 'weight(g)', 'inches', 'video_240fps']
X = phone_data[features]
y = phone_data['price_category']

# Preprocessing for numerical data
numerical_cols = X.columns
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols)
    ])

# Convert categorical labels to one-hot encoding
y = pd.get_dummies(y)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Applying preprocessing
X_train_transformed = preprocessor.fit_transform(X_train)
X_test_transformed = preprocessor.transform(X_test)

# Convert sparse matrix to dense (if necessary)
X_train_transformed = X_train_transformed.toarray() if hasattr(X_train_transformed, "toarray") else X_train_transformed
X_test_transformed = X_test_transformed.toarray() if hasattr(X_test_transformed, "toarray") else X_test_transformed

# Manual train-validation split
X_train_final, X_val, y_train_final, y_val = train_test_split(
    X_train_transformed, y_train, test_size=0.2, random_state=42)

# Building the ANN for Classification
model = Sequential([
    Dense(8, activation='tanh', input_shape=(X_train_final.shape[1],)),
    Dense(16, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')  # Output layer for the number of categories
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(
    X_train_final, y_train_final,
    epochs=100,
    validation_data=(X_val, y_val)
)

# Evaluate the model
loss, accuracy = model.evaluate(X_test_transformed, y_test)
print(f'Accuracy: {accuracy * 100:.2f}%')

# Plotting training and validation accuracy and loss
epochs = range(1, len(history.history['accuracy']) + 1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, history.history['accuracy'], label='Training acc')
plt.plot(epochs, history.history['val_accuracy'], label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, history.history['loss'],  label='Training loss')
plt.plot(epochs, history.history['val_loss'],  label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Predicting the Test set results
y_pred = model.predict(X_test_transformed)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test.to_numpy(), axis=1)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred_classes)
print("Confusion Matrix:")
print(cm)


# Plotting the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix for Logistic Regression Model')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# F1 Score
f1 = f1_score(y_true, y_pred_classes, average='weighted')
print(f"F1 Score: {f1}")

# Classification Report (includes F1 score for each class)
print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes))
# Out:
# Epoch 1/100
# 2023-12-08 20:43:52.853608: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-08 20:43:52.854246: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 31/31 [==============================] - 1s 8ms/step - loss: 1.4812 - accuracy: 0.2234 - val_loss: 1.4126 - val_accuracy: 0.2975
# Epoch 2/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.3427 - accuracy: 0.3961 - val_loss: 1.2873 - val_accuracy: 0.4132
# Epoch 3/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.2382 - accuracy: 0.4509 - val_loss: 1.1900 - val_accuracy: 0.4380
# Epoch 4/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.1572 - accuracy: 0.4695 - val_loss: 1.1210 - val_accuracy: 0.4463
# Epoch 5/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.1036 - accuracy: 0.4829 - val_loss: 1.0797 - val_accuracy: 0.4917
# Epoch 6/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.0708 - accuracy: 0.5481 - val_loss: 1.0471 - val_accuracy: 0.5496
# Epoch 7/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.0481 - accuracy: 0.5533 - val_loss: 1.0224 - val_accuracy: 0.5744
# Epoch 8/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.0323 - accuracy: 0.5615 - val_loss: 1.0014 - val_accuracy: 0.5868
# Epoch 9/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.0197 - accuracy: 0.5667 - val_loss: 0.9862 - val_accuracy: 0.6033
# Epoch 10/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0123 - accuracy: 0.5698 - val_loss: 0.9769 - val_accuracy: 0.6033
# Epoch 11/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.0062 - accuracy: 0.5688 - val_loss: 0.9700 - val_accuracy: 0.6033
# Epoch 12/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1.0020 - accuracy: 0.5729 - val_loss: 0.9642 - val_accuracy: 0.5950
# Epoch 13/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9993 - accuracy: 0.5750 - val_loss: 0.9616 - val_accuracy: 0.5950
# Epoch 14/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9963 - accuracy: 0.5739 - val_loss: 0.9584 - val_accuracy: 0.5992
# Epoch 15/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9939 - accuracy: 0.5750 - val_loss: 0.9561 - val_accuracy: 0.6116
# Epoch 16/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9922 - accuracy: 0.5801 - val_loss: 0.9545 - val_accuracy: 0.6074
# Epoch 17/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9906 - accuracy: 0.5781 - val_loss: 0.9540 - val_accuracy: 0.6074
# Epoch 18/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9888 - accuracy: 0.5801 - val_loss: 0.9542 - val_accuracy: 0.6116
# Epoch 19/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9872 - accuracy: 0.5739 - val_loss: 0.9510 - val_accuracy: 0.6033
# Epoch 20/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9856 - accuracy: 0.5781 - val_loss: 0.9515 - val_accuracy: 0.6198
# Epoch 21/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9839 - accuracy: 0.5770 - val_loss: 0.9510 - val_accuracy: 0.6074
# Epoch 22/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9830 - accuracy: 0.5760 - val_loss: 0.9492 - val_accuracy: 0.6116
# Epoch 23/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9811 - accuracy: 0.5770 - val_loss: 0.9509 - val_accuracy: 0.6074
# Epoch 24/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9798 - accuracy: 0.5770 - val_loss: 0.9498 - val_accuracy: 0.6033
# Epoch 25/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9793 - accuracy: 0.5781 - val_loss: 0.9489 - val_accuracy: 0.6116
# Epoch 26/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9782 - accuracy: 0.5760 - val_loss: 0.9517 - val_accuracy: 0.6074
# Epoch 27/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9774 - accuracy: 0.5781 - val_loss: 0.9498 - val_accuracy: 0.5992
# Epoch 28/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9749 - accuracy: 0.5781 - val_loss: 0.9503 - val_accuracy: 0.6116
# Epoch 29/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9736 - accuracy: 0.5760 - val_loss: 0.9496 - val_accuracy: 0.6116
# Epoch 30/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9735 - accuracy: 0.5801 - val_loss: 0.9487 - val_accuracy: 0.6074
# Epoch 31/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9719 - accuracy: 0.5791 - val_loss: 0.9493 - val_accuracy: 0.6033
# Epoch 32/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9711 - accuracy: 0.5770 - val_loss: 0.9485 - val_accuracy: 0.5950
# Epoch 33/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9698 - accuracy: 0.5853 - val_loss: 0.9493 - val_accuracy: 0.5992
# Epoch 34/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9690 - accuracy: 0.5863 - val_loss: 0.9498 - val_accuracy: 0.6033
# Epoch 35/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9687 - accuracy: 0.5853 - val_loss: 0.9519 - val_accuracy: 0.5992
# Epoch 36/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9673 - accuracy: 0.5884 - val_loss: 0.9514 - val_accuracy: 0.6033
# Epoch 37/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9666 - accuracy: 0.5853 - val_loss: 0.9508 - val_accuracy: 0.5992
# Epoch 38/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9661 - accuracy: 0.5791 - val_loss: 0.9502 - val_accuracy: 0.5992
# Epoch 39/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9652 - accuracy: 0.5843 - val_loss: 0.9490 - val_accuracy: 0.6033
# Epoch 40/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9644 - accuracy: 0.5863 - val_loss: 0.9495 - val_accuracy: 0.6033
# Epoch 41/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9638 - accuracy: 0.5895 - val_loss: 0.9499 - val_accuracy: 0.6074
# Epoch 42/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9628 - accuracy: 0.5863 - val_loss: 0.9498 - val_accuracy: 0.6074
# Epoch 43/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9629 - accuracy: 0.6019 - val_loss: 0.9517 - val_accuracy: 0.5826
# Epoch 44/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9614 - accuracy: 0.5936 - val_loss: 0.9490 - val_accuracy: 0.6033
# Epoch 45/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9605 - accuracy: 0.5946 - val_loss: 0.9509 - val_accuracy: 0.6033
# Epoch 46/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9604 - accuracy: 0.5977 - val_loss: 0.9505 - val_accuracy: 0.6033
# Epoch 47/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9596 - accuracy: 0.5957 - val_loss: 0.9522 - val_accuracy: 0.5950
# Epoch 48/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9591 - accuracy: 0.5936 - val_loss: 0.9517 - val_accuracy: 0.5950
# Epoch 49/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9583 - accuracy: 0.5967 - val_loss: 0.9507 - val_accuracy: 0.5826
# Epoch 50/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9573 - accuracy: 0.6008 - val_loss: 0.9535 - val_accuracy: 0.5868
# Epoch 51/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9566 - accuracy: 0.6029 - val_loss: 0.9519 - val_accuracy: 0.5826
# Epoch 52/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9564 - accuracy: 0.5988 - val_loss: 0.9512 - val_accuracy: 0.5950
# Epoch 53/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9559 - accuracy: 0.5998 - val_loss: 0.9502 - val_accuracy: 0.5826
# Epoch 54/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9554 - accuracy: 0.6070 - val_loss: 0.9535 - val_accuracy: 0.5909
# Epoch 55/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9546 - accuracy: 0.6039 - val_loss: 0.9529 - val_accuracy: 0.5868
# Epoch 56/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9546 - accuracy: 0.6143 - val_loss: 0.9545 - val_accuracy: 0.5909
# Epoch 57/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9536 - accuracy: 0.6163 - val_loss: 0.9528 - val_accuracy: 0.5950
# Epoch 58/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9539 - accuracy: 0.6081 - val_loss: 0.9515 - val_accuracy: 0.5909
# Epoch 59/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9540 - accuracy: 0.6081 - val_loss: 0.9563 - val_accuracy: 0.5826
# Epoch 60/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9521 - accuracy: 0.6143 - val_loss: 0.9519 - val_accuracy: 0.5826
# Epoch 61/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9518 - accuracy: 0.6070 - val_loss: 0.9518 - val_accuracy: 0.5826
# Epoch 62/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9506 - accuracy: 0.6153 - val_loss: 0.9549 - val_accuracy: 0.5909
# Epoch 63/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9504 - accuracy: 0.6143 - val_loss: 0.9549 - val_accuracy: 0.5950
# Epoch 64/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9497 - accuracy: 0.6143 - val_loss: 0.9523 - val_accuracy: 0.5909
# Epoch 65/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9497 - accuracy: 0.6143 - val_loss: 0.9522 - val_accuracy: 0.5909
# Epoch 66/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9492 - accuracy: 0.6112 - val_loss: 0.9547 - val_accuracy: 0.5868
# Epoch 67/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9484 - accuracy: 0.6163 - val_loss: 0.9537 - val_accuracy: 0.5868
# Epoch 68/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9479 - accuracy: 0.6132 - val_loss: 0.9533 - val_accuracy: 0.5950
# Epoch 69/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9479 - accuracy: 0.6112 - val_loss: 0.9542 - val_accuracy: 0.5909
# Epoch 70/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9476 - accuracy: 0.6174 - val_loss: 0.9547 - val_accuracy: 0.5702
# Epoch 71/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9480 - accuracy: 0.6153 - val_loss: 0.9562 - val_accuracy: 0.5868
# Epoch 72/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9458 - accuracy: 0.6122 - val_loss: 0.9556 - val_accuracy: 0.5785
# Epoch 73/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9463 - accuracy: 0.6143 - val_loss: 0.9573 - val_accuracy: 0.5785
# Epoch 74/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9461 - accuracy: 0.6184 - val_loss: 0.9564 - val_accuracy: 0.5702
# Epoch 75/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9455 - accuracy: 0.6174 - val_loss: 0.9585 - val_accuracy: 0.5909
# Epoch 76/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9454 - accuracy: 0.6153 - val_loss: 0.9548 - val_accuracy: 0.5909
# Epoch 77/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9451 - accuracy: 0.6143 - val_loss: 0.9568 - val_accuracy: 0.5785
# Epoch 78/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9439 - accuracy: 0.6153 - val_loss: 0.9579 - val_accuracy: 0.5785
# Epoch 79/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9437 - accuracy: 0.6163 - val_loss: 0.9568 - val_accuracy: 0.5785
# Epoch 80/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9437 - accuracy: 0.6163 - val_loss: 0.9576 - val_accuracy: 0.5909
# Epoch 81/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9427 - accuracy: 0.6132 - val_loss: 0.9567 - val_accuracy: 0.5826
# Epoch 82/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9426 - accuracy: 0.6132 - val_loss: 0.9578 - val_accuracy: 0.5909
# Epoch 83/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9421 - accuracy: 0.6153 - val_loss: 0.9579 - val_accuracy: 0.5909
# Epoch 84/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9414 - accuracy: 0.6153 - val_loss: 0.9584 - val_accuracy: 0.5909
# Epoch 85/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9410 - accuracy: 0.6132 - val_loss: 0.9594 - val_accuracy: 0.5785
# Epoch 86/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9410 - accuracy: 0.6194 - val_loss: 0.9589 - val_accuracy: 0.5744
# Epoch 87/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9409 - accuracy: 0.6153 - val_loss: 0.9553 - val_accuracy: 0.5826
# Epoch 88/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9397 - accuracy: 0.6112 - val_loss: 0.9603 - val_accuracy: 0.5826
# Epoch 89/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9399 - accuracy: 0.6184 - val_loss: 0.9602 - val_accuracy: 0.5992
# Epoch 90/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9391 - accuracy: 0.6122 - val_loss: 0.9603 - val_accuracy: 0.5785
# Epoch 91/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9386 - accuracy: 0.6174 - val_loss: 0.9602 - val_accuracy: 0.5785
# Epoch 92/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9379 - accuracy: 0.6184 - val_loss: 0.9579 - val_accuracy: 0.5744
# Epoch 93/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9374 - accuracy: 0.6153 - val_loss: 0.9590 - val_accuracy: 0.5785
# Epoch 94/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9368 - accuracy: 0.6153 - val_loss: 0.9600 - val_accuracy: 0.5868
# Epoch 95/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9362 - accuracy: 0.6163 - val_loss: 0.9614 - val_accuracy: 0.5785
# Epoch 96/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9360 - accuracy: 0.6163 - val_loss: 0.9583 - val_accuracy: 0.5909
# Epoch 97/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9351 - accuracy: 0.6194 - val_loss: 0.9620 - val_accuracy: 0.5744
# Epoch 98/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9350 - accuracy: 0.6153 - val_loss: 0.9608 - val_accuracy: 0.5909
# Epoch 99/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9347 - accuracy: 0.6184 - val_loss: 0.9630 - val_accuracy: 0.5909
# Epoch 100/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9346 - accuracy: 0.6143 - val_loss: 0.9584 - val_accuracy: 0.5826
# 10/10 [==============================] - 0s 2ms/step - loss: 0.9224 - accuracy: 0.6139
# Accuracy: 61.39%
# 10/10 [==============================] - 0s 2ms/step
# Confusion Matrix:
# [[107  37   4   0]
#  [ 37  73   4   0]
#  [  5  19   4   0]
#  [  3   5   3   2]]
# F1 Score: 0.5985551338329632
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.72      0.71       148
#            1       0.54      0.64      0.59       114
#            2       0.27      0.14      0.19        28
#            3       1.00      0.15      0.27        13
#
#     accuracy                           0.61       303
#    macro avg       0.63      0.42      0.44       303
# weighted avg       0.62      0.61      0.60       303
