# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('cleaned_all_phones.csv') 

df['announcement_date'] = pd.to_datetime(df['announcement_date'])
if 'resolution' in df.columns:
# Split 'resolution' into two separate columns 'resolution_width' and 'resolution_height'
    df['resolution_width'] = df['resolution'].apply(lambda x: int(x.split('x')[0]))
    df['resolution_height'] = df['resolution'].apply(lambda x: int(x.split('x')[1]))

# Drop the original 'resolution' column
df.drop('resolution', axis=1, inplace=True)

# Display the first few rows of the dataset after transformations
df.head()
# Out:
#        phone_name   brand           os  inches  battery battery_type  ram(GB)  \
# 0    Y6II Compact  Huawei  Android 5.1     5.0     2200        Li-Po        2
# 1        K20 plus      LG  Android 7.0     5.3     2700       Li-Ion        2
# 2  P8 Lite (2017)  Huawei  Android 7.0     5.2     3000       Li-Ion        4
# 3    Redmi Note 4  Xiaomi  Android 6.0     5.5     4100        Li-Po        4
# 4             P10  Huawei  Android 7.0     5.1     3200       Li-Ion        4
#
#   announcement_date  weight(g)  storage(GB)  ...  video_8K  video_30fps  \
# 0        2016-09-01      140.0           16  ...     False         True
# 1        2016-12-01      140.0           16  ...     False         True
# 2        2017-01-01      147.0           16  ...     False         True
# 3        2017-01-01      165.0           32  ...     False         True
# 4        2017-02-01      145.0           32  ...     False         True
#
# ...

# %% [raw]
# OUTLIERS

# %%
numerical_cols = ['inches', 'battery', 'ram(GB)', 'weight(g)', 'storage(GB)', 'price(USD)', 'resolution_width', 'resolution_height']

# Plot boxplots for each numerical column to inspect for outliers
plt.figure(figsize=(12, 10))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(4, 2, i)
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.tight_layout()

plt.show()
# Out:
# /var/folders/27/t79xn6w50wl5t6_gt65njxh40000gn/T/ipykernel_67374/844091613.py:9: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/27/t79xn6w50wl5t6_gt65njxh40000gn/T/ipykernel_67374/844091613.py:9: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/27/t79xn6w50wl5t6_gt65njxh40000gn/T/ipykernel_67374/844091613.py:9: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/27/t79xn6w50wl5t6_gt65njxh40000gn/T/ipykernel_67374/844091613.py:9: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/27/t79xn6w50wl5t6_gt65njxh40000gn/T/ipykernel_67374/844091613.py:9: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/27/t79xn6w50wl5t6_gt65njxh40000gn/T/ipykernel_67374/844091613.py:9: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# ...

# %% [raw]
# inches: outliers - some phones with a size less than 2 inches and  greater than 7 inches
#
# battery: outliers - battery capacities beyond 6000mAh
#
# ram(GB):outliers -  RAM up to 16GB.
#
# weight(g):outliers -  phones weigh more than 300g
#
# storage(GB):outliers - storage between 8GB and 512GB???
#
# price(USD): outliers -  prices beyond $1500?????
#  ---nova 6 5G - $2150.0?????
#  ----

# %% [raw]
# Duplicate data

# %%
duplicate_rows = df[df.duplicated()]
num_duplicates = duplicate_rows.shape[0]

print(num_duplicates)
# Out:
# 0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('train.csv') 

missing_values_train = df.isnull().sum()
missing_values_train


data_types_train = df.dtypes
data_types_train
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
numerical_cols_train = df.columns[:-1] 

plt.figure(figsize=(20, 15))
for i, col in enumerate(numerical_cols_train, 1):
    plt.subplot(5, 4, i)
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.tight_layout()

plt.show()
# Out:
# /var/folders/27/t79xn6w50wl5t6_gt65njxh40000gn/T/ipykernel_67374/424595727.py:8: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/27/t79xn6w50wl5t6_gt65njxh40000gn/T/ipykernel_67374/424595727.py:8: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/27/t79xn6w50wl5t6_gt65njxh40000gn/T/ipykernel_67374/424595727.py:8: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/27/t79xn6w50wl5t6_gt65njxh40000gn/T/ipykernel_67374/424595727.py:8: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/27/t79xn6w50wl5t6_gt65njxh40000gn/T/ipykernel_67374/424595727.py:8: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/27/t79xn6w50wl5t6_gt65njxh40000gn/T/ipykernel_67374/424595727.py:8: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# ...

# %% [raw]
# Duplicate data

# %%
duplicate_rows = df[df.duplicated()]
num_duplicates = duplicate_rows.shape[0]

print(num_duplicates)
# Out:
# 0
