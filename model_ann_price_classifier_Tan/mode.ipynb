# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import confusion_matrix, f1_score, classification_report
import numpy as np
import seaborn as sns
# Load the dataset
file_path = '../data/cleaned_all_phones.csv'
phone_data = pd.read_csv(file_path)

# Define custom price categories
bins = [0, 250, 500, 1000, phone_data['price(USD)'].max()]
labels = ['0-250', '251-500', '501-1000', '1000+']
phone_data['price_category'] = pd.cut(phone_data['price(USD)'], bins=bins, labels=labels, right=False)

# Selecting features and target variable
features = ['storage(GB)', 'video_4K', 'video_720p', 'ram(GB)', 'video_60fps', 'weight(g)', 'inches', 'video_240fps']
X = phone_data[features]
y = phone_data['price_category']

# Preprocessing for numerical data
numerical_cols = X.columns
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols)
    ])

# Convert categorical labels to one-hot encoding
y = pd.get_dummies(y)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Applying preprocessing
X_train_transformed = preprocessor.fit_transform(X_train)
X_test_transformed = preprocessor.transform(X_test)

# Convert sparse matrix to dense (if necessary)
X_train_transformed = X_train_transformed.toarray() if hasattr(X_train_transformed, "toarray") else X_train_transformed
X_test_transformed = X_test_transformed.toarray() if hasattr(X_test_transformed, "toarray") else X_test_transformed

# Manual train-validation split
X_train_final, X_val, y_train_final, y_val = train_test_split(
    X_train_transformed, y_train, test_size=0.2, random_state=42)

# Building the ANN for Classification
model = Sequential([
    Dense(8, activation='tanh', input_shape=(X_train_final.shape[1],)),
    Dense(16, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')  # Output layer for the number of categories
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(
    X_train_final, y_train_final,
    epochs=100,
    validation_data=(X_val, y_val)
)

# Evaluate the model
loss, accuracy = model.evaluate(X_test_transformed, y_test)
print(f'Accuracy: {accuracy * 100:.2f}%')

# Plotting training and validation accuracy and loss
epochs = range(1, len(history.history['accuracy']) + 1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, history.history['accuracy'], label='Training acc')
plt.plot(epochs, history.history['val_accuracy'], label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, history.history['loss'],  label='Training loss')
plt.plot(epochs, history.history['val_loss'],  label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Predicting the Test set results
y_pred = model.predict(X_test_transformed)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test.to_numpy(), axis=1)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred_classes)
print("Confusion Matrix:")
print(cm)


# Plotting the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix for Logistic Regression Model')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# F1 Score
f1 = f1_score(y_true, y_pred_classes, average='weighted')
print(f"F1 Score: {f1}")

# Classification Report (includes F1 score for each class)
print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes))
# Out:
# 2023-12-03 18:10:24.572371: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-03 18:10:24.595495: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-03 18:10:24.977137: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-03 18:10:25.465985: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-03 18:10:25.478809: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-03 18:10:25.478846: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-03 18:10:25.480682: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-03 18:10:25.480713: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-03 18:10:25.480726: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-03 18:10:26.000355: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-03 18:10:26.000413: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-03 18:10:26.000419: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1726] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-12-03 18:10:26.000441: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to r
# Epoch 1/100
# ead NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-12-03 18:10:26.000462: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13340 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2023-12-03 18:10:27.340994: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-12-03 18:10:27.349705: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fb73003aa90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-03 18:10:27.349735: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4080, Compute Capability 8.9
# 2023-12-03 18:10:27.353029: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-03 18:10:27.465140: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-12-03 18:10:27.498225: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:231] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2023-12-03 18:10:27.498247: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Used ptxas at ptxas
# 2023-12-03 18:10:27.498281: W tensorflow/compiler/xla/service/gpu/nvptx_compiler.cc:332] Couldn't read CUDA driver version.
# 2023-12-03 18:10:27.507885: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 31/31 [==============================] - 2s 8ms/step - loss: 1.5000 - accuracy: 0.1655 - val_loss: 1.4045 - val_accuracy: 0.2686
# Epoch 2/100
# 31/31 [==============================] - 0s 5ms/step - loss: 1.3527 - accuracy: 0.3206 - val_loss: 1.2764 - val_accuracy: 0.4752
# Epoch 3/100
# 31/31 [==============================] - 0s 5ms/step - loss: 1.2535 - accuracy: 0.4747 - val_loss: 1.1850 - val_accuracy: 0.5620
# Epoch 4/100
# 31/31 [==============================] - 0s 6ms/step - loss: 1.1784 - accuracy: 0.5460 - val_loss: 1.1131 - val_accuracy: 0.5785
# Epoch 5/100
# 31/31 [==============================] - 0s 5ms/step - loss: 1.1221 - accuracy: 0.5646 - val_loss: 1.0589 - val_accuracy: 0.5909
# Epoch 6/100
# 31/31 [==============================] - 0s 6ms/step - loss: 1.0797 - accuracy: 0.5760 - val_loss: 1.0216 - val_accuracy: 0.5909
# Epoch 7/100
# 31/31 [==============================] - 0s 5ms/step - loss: 1.0521 - accuracy: 0.5729 - val_loss: 0.9971 - val_accuracy: 0.5909
# Epoch 8/100
# 31/31 [==============================] - 0s 6ms/step - loss: 1.0350 - accuracy: 0.5698 - val_loss: 0.9800 - val_accuracy: 0.5909
# Epoch 9/100
# 31/31 [==============================] - 0s 6ms/step - loss: 1.0251 - accuracy: 0.5729 - val_loss: 0.9694 - val_accuracy: 0.5950
# Epoch 10/100
# 31/31 [==============================] - 0s 6ms/step - loss: 1.0175 - accuracy: 0.5739 - val_loss: 0.9647 - val_accuracy: 0.5909
# Epoch 11/100
# 31/31 [==============================] - 0s 5ms/step - loss: 1.0127 - accuracy: 0.5750 - val_loss: 0.9587 - val_accuracy: 0.6033
# Epoch 12/100
# 31/31 [==============================] - 0s 5ms/step - loss: 1.0081 - accuracy: 0.5750 - val_loss: 0.9544 - val_accuracy: 0.5950
# Epoch 13/100
# 31/31 [==============================] - 0s 6ms/step - loss: 1.0048 - accuracy: 0.5760 - val_loss: 0.9512 - val_accuracy: 0.5992
# Epoch 14/100
# 31/31 [==============================] - 0s 6ms/step - loss: 1.0015 - accuracy: 0.5750 - val_loss: 0.9478 - val_accuracy: 0.6033
# Epoch 15/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9994 - accuracy: 0.5812 - val_loss: 0.9450 - val_accuracy: 0.6033
# Epoch 16/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9962 - accuracy: 0.5843 - val_loss: 0.9435 - val_accuracy: 0.6033
# Epoch 17/100
# 31/31 [==============================] - 0s 7ms/step - loss: 0.9941 - accuracy: 0.5843 - val_loss: 0.9427 - val_accuracy: 0.6116
# Epoch 18/100
# 31/31 [==============================] - 0s 7ms/step - loss: 0.9926 - accuracy: 0.5832 - val_loss: 0.9416 - val_accuracy: 0.6033
# Epoch 19/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9908 - accuracy: 0.5884 - val_loss: 0.9393 - val_accuracy: 0.6074
# Epoch 20/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9892 - accuracy: 0.5863 - val_loss: 0.9375 - val_accuracy: 0.6033
# Epoch 21/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9869 - accuracy: 0.5843 - val_loss: 0.9373 - val_accuracy: 0.6116
# Epoch 22/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9854 - accuracy: 0.5905 - val_loss: 0.9380 - val_accuracy: 0.6074
# Epoch 23/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9846 - accuracy: 0.5853 - val_loss: 0.9385 - val_accuracy: 0.5950
# Epoch 24/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9824 - accuracy: 0.5884 - val_loss: 0.9371 - val_accuracy: 0.5909
# Epoch 25/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9817 - accuracy: 0.5895 - val_loss: 0.9362 - val_accuracy: 0.5826
# Epoch 26/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9801 - accuracy: 0.5926 - val_loss: 0.9354 - val_accuracy: 0.5826
# Epoch 27/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9785 - accuracy: 0.5926 - val_loss: 0.9367 - val_accuracy: 0.5909
# Epoch 28/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9770 - accuracy: 0.5895 - val_loss: 0.9368 - val_accuracy: 0.5868
# Epoch 29/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9763 - accuracy: 0.5946 - val_loss: 0.9377 - val_accuracy: 0.5950
# Epoch 30/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9753 - accuracy: 0.5926 - val_loss: 0.9392 - val_accuracy: 0.5826
# Epoch 31/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9742 - accuracy: 0.5957 - val_loss: 0.9366 - val_accuracy: 0.5909
# Epoch 32/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9733 - accuracy: 0.5936 - val_loss: 0.9373 - val_accuracy: 0.5826
# Epoch 33/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9722 - accuracy: 0.5946 - val_loss: 0.9382 - val_accuracy: 0.5868
# Epoch 34/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9717 - accuracy: 0.5977 - val_loss: 0.9377 - val_accuracy: 0.5909
# Epoch 35/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9710 - accuracy: 0.5926 - val_loss: 0.9378 - val_accuracy: 0.5826
# Epoch 36/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9703 - accuracy: 0.5946 - val_loss: 0.9371 - val_accuracy: 0.5826
# Epoch 37/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9690 - accuracy: 0.5988 - val_loss: 0.9389 - val_accuracy: 0.5868
# Epoch 38/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9685 - accuracy: 0.5957 - val_loss: 0.9373 - val_accuracy: 0.5744
# Epoch 39/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9679 - accuracy: 0.5967 - val_loss: 0.9360 - val_accuracy: 0.5785
# Epoch 40/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9671 - accuracy: 0.5967 - val_loss: 0.9365 - val_accuracy: 0.5785
# Epoch 41/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9673 - accuracy: 0.5936 - val_loss: 0.9375 - val_accuracy: 0.5785
# Epoch 42/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9665 - accuracy: 0.5977 - val_loss: 0.9397 - val_accuracy: 0.5744
# Epoch 43/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9656 - accuracy: 0.5926 - val_loss: 0.9383 - val_accuracy: 0.5744
# Epoch 44/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9649 - accuracy: 0.5988 - val_loss: 0.9402 - val_accuracy: 0.5785
# Epoch 45/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9652 - accuracy: 0.5988 - val_loss: 0.9374 - val_accuracy: 0.5868
# Epoch 46/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9635 - accuracy: 0.5946 - val_loss: 0.9379 - val_accuracy: 0.5744
# Epoch 47/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9633 - accuracy: 0.6019 - val_loss: 0.9382 - val_accuracy: 0.5868
# Epoch 48/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9622 - accuracy: 0.6008 - val_loss: 0.9384 - val_accuracy: 0.5702
# Epoch 49/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9618 - accuracy: 0.6008 - val_loss: 0.9375 - val_accuracy: 0.5785
# Epoch 50/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9620 - accuracy: 0.6029 - val_loss: 0.9377 - val_accuracy: 0.5744
# Epoch 51/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9613 - accuracy: 0.5967 - val_loss: 0.9386 - val_accuracy: 0.5826
# Epoch 52/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.9602 - accuracy: 0.6029 - val_loss: 0.9396 - val_accuracy: 0.5744
# Epoch 53/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9602 - accuracy: 0.6019 - val_loss: 0.9389 - val_accuracy: 0.5744
# Epoch 54/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9591 - accuracy: 0.6029 - val_loss: 0.9388 - val_accuracy: 0.5744
# Epoch 55/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9590 - accuracy: 0.6008 - val_loss: 0.9397 - val_accuracy: 0.5785
# Epoch 56/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9594 - accuracy: 0.6019 - val_loss: 0.9412 - val_accuracy: 0.5702
# Epoch 57/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9577 - accuracy: 0.6029 - val_loss: 0.9396 - val_accuracy: 0.5744
# Epoch 58/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9573 - accuracy: 0.6029 - val_loss: 0.9393 - val_accuracy: 0.5744
# Epoch 59/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9570 - accuracy: 0.6039 - val_loss: 0.9399 - val_accuracy: 0.5744
# Epoch 60/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9566 - accuracy: 0.6039 - val_loss: 0.9415 - val_accuracy: 0.5785
# Epoch 61/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9559 - accuracy: 0.6039 - val_loss: 0.9410 - val_accuracy: 0.5785
# Epoch 62/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9555 - accuracy: 0.6019 - val_loss: 0.9402 - val_accuracy: 0.5785
# Epoch 63/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9551 - accuracy: 0.6060 - val_loss: 0.9399 - val_accuracy: 0.5744
# Epoch 64/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9543 - accuracy: 0.5988 - val_loss: 0.9408 - val_accuracy: 0.5744
# Epoch 65/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9531 - accuracy: 0.6039 - val_loss: 0.9414 - val_accuracy: 0.5744
# Epoch 66/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9535 - accuracy: 0.6060 - val_loss: 0.9419 - val_accuracy: 0.5744
# Epoch 67/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9523 - accuracy: 0.6070 - val_loss: 0.9417 - val_accuracy: 0.5785
# Epoch 68/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9527 - accuracy: 0.6019 - val_loss: 0.9401 - val_accuracy: 0.5785
# Epoch 69/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9520 - accuracy: 0.6050 - val_loss: 0.9427 - val_accuracy: 0.5702
# Epoch 70/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9515 - accuracy: 0.6070 - val_loss: 0.9421 - val_accuracy: 0.5744
# Epoch 71/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9510 - accuracy: 0.6039 - val_loss: 0.9420 - val_accuracy: 0.5744
# Epoch 72/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9524 - accuracy: 0.6008 - val_loss: 0.9418 - val_accuracy: 0.5702
# Epoch 73/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9499 - accuracy: 0.6029 - val_loss: 0.9436 - val_accuracy: 0.5744
# Epoch 74/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9503 - accuracy: 0.6008 - val_loss: 0.9431 - val_accuracy: 0.5702
# Epoch 75/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9495 - accuracy: 0.6050 - val_loss: 0.9449 - val_accuracy: 0.5785
# Epoch 76/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9492 - accuracy: 0.6070 - val_loss: 0.9443 - val_accuracy: 0.5744
# Epoch 77/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9488 - accuracy: 0.6029 - val_loss: 0.9434 - val_accuracy: 0.5744
# Epoch 78/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9489 - accuracy: 0.5998 - val_loss: 0.9444 - val_accuracy: 0.5785
# Epoch 79/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9474 - accuracy: 0.6019 - val_loss: 0.9444 - val_accuracy: 0.5785
# Epoch 80/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9470 - accuracy: 0.6029 - val_loss: 0.9446 - val_accuracy: 0.5744
# Epoch 81/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9468 - accuracy: 0.5988 - val_loss: 0.9444 - val_accuracy: 0.5744
# Epoch 82/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9461 - accuracy: 0.6019 - val_loss: 0.9457 - val_accuracy: 0.5744
# Epoch 83/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9462 - accuracy: 0.6008 - val_loss: 0.9452 - val_accuracy: 0.5744
# Epoch 84/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9454 - accuracy: 0.6029 - val_loss: 0.9458 - val_accuracy: 0.5744
# Epoch 85/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9455 - accuracy: 0.6060 - val_loss: 0.9447 - val_accuracy: 0.5702
# Epoch 86/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9454 - accuracy: 0.6019 - val_loss: 0.9435 - val_accuracy: 0.5744
# Epoch 87/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9449 - accuracy: 0.6008 - val_loss: 0.9449 - val_accuracy: 0.5702
# Epoch 88/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9450 - accuracy: 0.6081 - val_loss: 0.9469 - val_accuracy: 0.5702
# Epoch 89/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9439 - accuracy: 0.6070 - val_loss: 0.9447 - val_accuracy: 0.5744
# Epoch 90/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9437 - accuracy: 0.6070 - val_loss: 0.9464 - val_accuracy: 0.5702
# Epoch 91/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9434 - accuracy: 0.6050 - val_loss: 0.9457 - val_accuracy: 0.5702
# Epoch 92/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9427 - accuracy: 0.6060 - val_loss: 0.9462 - val_accuracy: 0.5744
# Epoch 93/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9424 - accuracy: 0.6091 - val_loss: 0.9474 - val_accuracy: 0.5702
# Epoch 94/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9421 - accuracy: 0.6050 - val_loss: 0.9460 - val_accuracy: 0.5702
# Epoch 95/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9421 - accuracy: 0.6112 - val_loss: 0.9479 - val_accuracy: 0.5785
# Epoch 96/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9438 - accuracy: 0.6060 - val_loss: 0.9473 - val_accuracy: 0.5702
# Epoch 97/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9418 - accuracy: 0.6091 - val_loss: 0.9467 - val_accuracy: 0.5702
# Epoch 98/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9406 - accuracy: 0.6081 - val_loss: 0.9476 - val_accuracy: 0.5744
# Epoch 99/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9410 - accuracy: 0.6081 - val_loss: 0.9482 - val_accuracy: 0.5702
# Epoch 100/100
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9400 - accuracy: 0.6091 - val_loss: 0.9479 - val_accuracy: 0.5702
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9231 - accuracy: 0.6040
# Accuracy: 60.40%
# 10/10 [==============================] - 0s 2ms/step
# Confusion Matrix:
# [[108  36   4   0]
#  [ 41  69   4   0]
#  [  5  19   4   0]
#  [  3   5   3   2]]
# F1 Score: 0.5882172425316408
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.73      0.71       148
#            1       0.53      0.61      0.57       114
#            2       0.27      0.14      0.19        28
#            3       1.00      0.15      0.27        13
#
#     accuracy                           0.60       303
#    macro avg       0.62      0.41      0.43       303
# weighted avg       0.60      0.60      0.59       303
